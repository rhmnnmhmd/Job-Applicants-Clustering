# %%
import pandas as pd

import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn import datasets
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn import metrics as sm
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.metrics import adjusted_rand_score

import seaborn as sns

# %% [markdown]
# # import data from excel

# %%
df = pd.read_excel('Jobstreet_Data.xlsx')
df
# Out:
#                            Position Title Expected Salary Experience  \
# 0             Graduate Research Assistant               -          0
# 1      Graduated Research Assistant (GRA)               -          0
# 2                    People System Intern               -          0
# 3                                       -               -          0
# 4                                  Intern               -          0
# ...                                   ...             ...        ...
# 2171           Senior Production Engineer       MYR 7,900   10 years
# 2172                          QA Engineer       SGD 3,200    3 years
# 2173     Section Head II (Quality System)       MYR 8,800   38 years
# 2174                   Equipment Engineer       MYR 9,000   15 years
# 2175  Sr Quality and Reliability Engineer      MYR 12,000   23 years
#
#      Education Level        Specialization
# 0             Master    Civil/Construction
# 1             Master  Science & Technology
# 2        Bach Degree           Advertising
# 3        Bach Degree                     -
# 4        Bach Degree     Other Engineering
# ...              ...                   ...
# 2171     Bach Degree     Other Engineering
# 2172          Master       Quality Control
# 2173       Prof Cert       Quality Control
# 2174     Bach Degree            Electrical
# 2175         Diploma       Quality Control
#
# [2176 rows x 5 columns]

# %% [markdown]
# # general infos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2176 entries, 0 to 2175
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position Title   2176 non-null   object
#  1   Expected Salary  2176 non-null   object
#  2   Experience       2176 non-null   object
#  3   Education Level  2176 non-null   object
#  4   Specialization   2176 non-null   object
# dtypes: object(5)
# memory usage: 85.1+ KB

# %% [markdown]
# # description of each columns

# %%
df.describe()
# Out:
#        Position Title Expected Salary  Experience Education Level  \
# count            2176            2176        2176            2176
# unique           1097              79          25              11
# top                 -       MYR 2,500           0     Bach Degree
# freq              132             393        1026            1971
#
#        Specialization
# count            2176
# unique             56
# top     Manufacturing
# freq              288

# %% [markdown]
# # rename columns

# %%
df.columns = ['pos', 'sal', 'exp', 'edu', 'spec']
df
# Out:
#                                       pos         sal       exp          edu  \
# 0             Graduate Research Assistant           -         0       Master
# 1      Graduated Research Assistant (GRA)           -         0       Master
# 2                    People System Intern           -         0  Bach Degree
# 3                                       -           -         0  Bach Degree
# 4                                  Intern           -         0  Bach Degree
# ...                                   ...         ...       ...          ...
# 2171           Senior Production Engineer   MYR 7,900  10 years  Bach Degree
# 2172                          QA Engineer   SGD 3,200   3 years       Master
# 2173     Section Head II (Quality System)   MYR 8,800  38 years    Prof Cert
# 2174                   Equipment Engineer   MYR 9,000  15 years  Bach Degree
# 2175  Sr Quality and Reliability Engineer  MYR 12,000  23 years      Diploma
#
#                       spec
# 0       Civil/Construction
# 1     Science & Technology
# 2              Advertising
# 3                        -
# 4        Other Engineering
# ...                    ...
# 2171     Other Engineering
# 2172       Quality Control
# 2173       Quality Control
# 2174            Electrical
# 2175       Quality Control
#
# [2176 rows x 5 columns]

# %% [markdown]
# # lower case all strings

# %%
toLowerCase = ['pos', 'edu', 'spec']

for column in toLowerCase:
    df[column] = df[column].str.lower()

df
# Out:
#                                       pos         sal       exp          edu  \
# 0             graduate research assistant           -         0       master
# 1      graduated research assistant (gra)           -         0       master
# 2                    people system intern           -         0  bach degree
# 3                                       -           -         0  bach degree
# 4                                  intern           -         0  bach degree
# ...                                   ...         ...       ...          ...
# 2171           senior production engineer   MYR 7,900  10 years  bach degree
# 2172                          qa engineer   SGD 3,200   3 years       master
# 2173     section head ii (quality system)   MYR 8,800  38 years    prof cert
# 2174                   equipment engineer   MYR 9,000  15 years  bach degree
# 2175  sr quality and reliability engineer  MYR 12,000  23 years      diploma
#
#                       spec
# 0       civil/construction
# 1     science & technology
# 2              advertising
# 3                        -
# 4        other engineering
# ...                    ...
# 2171     other engineering
# 2172       quality control
# 2173       quality control
# 2174            electrical
# 2175       quality control
#
# [2176 rows x 5 columns]

# %% [markdown]
# # handle exp column

# %%
import re
## initial/default method
# df['exp'] = df['exp'].str.strip().str.replace(' years', '').fillna('0')
# df['exp'] = df['exp'].str.strip().str.replace(' year', '').fillna('0')



## method regex
# df['exp'].str.extract(r'(\d+)', expand=False)

# df['exp'] = re.sub("[a-zA-Z]", "", df['exp'])

## method np.where from stackoverflow
# np.where(df['exp'] != '0', 
#          df['exp'].str.strip().str.replace(' years', ''), 
#          df['exp'])

## method ghidwan
# convert 'object' to 'str'
df['exp'] = df['exp'].astype(str)

# function to change string
def cleanTweets(column):
    column = re.sub('[a-zA-Z]', '', column)
    return column

# go through each row in the selected column
for row in df.itertuples():
        df.at[row.Index, 'exp',] = cleanTweets(row.exp)

# convert str to int
df['exp'] = df['exp'].astype(int)

df
# Out:
#                                       pos         sal  exp          edu  \
# 0             graduate research assistant           -    0       master
# 1      graduated research assistant (gra)           -    0       master
# 2                    people system intern           -    0  bach degree
# 3                                       -           -    0  bach degree
# 4                                  intern           -    0  bach degree
# ...                                   ...         ...  ...          ...
# 2171           senior production engineer   MYR 7,900   10  bach degree
# 2172                          qa engineer   SGD 3,200    3       master
# 2173     section head ii (quality system)   MYR 8,800   38    prof cert
# 2174                   equipment engineer   MYR 9,000   15  bach degree
# 2175  sr quality and reliability engineer  MYR 12,000   23      diploma
#
#                       spec
# 0       civil/construction
# 1     science & technology
# 2              advertising
# 3                        -
# 4        other engineering
# ...                    ...
# 2171     other engineering
# 2172       quality control
# 2173       quality control
# 2174            electrical
# 2175       quality control
#
# [2176 rows x 5 columns]

# %% [markdown]
# # handle salary column

# %% [markdown]
# ## Method 1 (Affine's method)

# %%
#  select all rows in 'sal' column with value starts with 'MYR'
condition = df['sal'].str.startswith('MYR')
df = df[condition].reset_index(drop = True)

# replace 'MYR ' with ''
df['sal'] = df['sal'].str.replace('MYR ', '')

# remove ',' and convert string/object to int
df['sal'] = df['sal'].str.replace('[^a-zA-Z0-9]', '').astype(int)

df
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_13988/153897430.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sal'] = df['sal'].str.replace('[^a-zA-Z0-9]', '').astype(int)
#                                       pos    sal  exp          edu  \
# 0                      internship student      1    0  bach degree
# 1              junior biomedical engineer      1    0  bach degree
# 2                          fresh graduate      1    0  bach degree
# 3                                       -      1    0  bach degree
# 4               research assistant intern      1    1  bach degree
# ...                                   ...    ...  ...          ...
# 2076              senior project engineer   7888   15       master
# 2077           senior production engineer   7900   10  bach degree
# 2078     section head ii (quality system)   8800   38    prof cert
# 2079                   equipment engineer   9000   15  bach degree
# 2080  sr quality and reliability engineer  12000   23      diploma
#
#                       spec
# 0            manufacturing
# 1            manufacturing
# 2               electrical
# 3                        -
# 4     chemical engineering
# ...                    ...
# 2076    civil/construction
# 2077     other engineering
# 2078       quality control
# 2079            electrical
# 2080       quality control
#
# [2081 rows x 5 columns]

# %% [markdown]
# ## Method 2:
# * change '-' to NA
# * drop 'SGD'
# * fill NA with median

# %%
# change '-' in sal column into NaN
df['sal'].replace('-', np.NaN)

# drop 'SGD' and reset index
df.drop(2172).reset_index(drop = True)

# fill NA with median
df['sal'].fillna(df['sal'].median())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13988/2052001619.py in <module>
#       3
#       4 # drop 'SGD' and reset index
# ----> 5 df.drop(2172).reset_index(drop = True)
#       6
#       7 # fill NA with median
#
# C:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: '[2172] not found in axis'

# %% [markdown]
# # Handling 'pos' column

# %%
df['pos'].value_counts()
# we can see below, there are 116 entries of '-' in the pos column

# %%
# select rows where pos not equal to '-'
df = df[df['pos'] != '-']
df

# %% [markdown]
# # Handling spec column

# %%
df['spec'].value_counts().sort_index()
#there are 78 entries with '-' as the value

# %%
#we remove this
df = df[df['spec'] != '-']
df

# %%
# change 'chemical engineering' and 'chemistry' to 'chemistry-related'
df['spec'] = np.where((df['spec'] == 'chemical engineering') | (df['spec'] == 'chemistry'), 'chemistry-related', df['spec'])

# change 'it-hardware' and 'it-network/sys/db admin' to 'it'
df['spec'] = np.where((df['spec'] == 'it-hardware') | (df['spec'] == 'it-network/sys/db admin') | (df['spec'] == 'it-software'), 
                      'it', df['spec'])

# change 'electronics' and 'electrical' to 'electric-related'
df['spec'] = np.where((df['spec'] == 'electronics') | (df['spec'] == 'electrical'), 'electric-related', df['spec'])

# change 'food tech/nutritionist ' and 'food/beverage/restaurant' to 'food'
df['spec'] = np.where((df['spec'] == 'food tech/nutritionist') | (df['spec'] == 'food/beverage/restaurant'), 'food', df['spec'])

# change more things lmao
df['spec'] = np.where((df['spec'] == 'sales-corporate') | (df['spec'] == 'sales-eng/tech/it') | (df['spec'] == 'sales-financial services') 
                      | (df['spec'] == 'sales-retail/general'), 'sales', df['spec'])

df
# Out:
#                                       pos    sal  exp          edu  \
# 0                      internship student      1    0  bach degree
# 1              junior biomedical engineer      1    0  bach degree
# 2                          fresh graduate      1    0  bach degree
# 3                                       -      1    0  bach degree
# 4               research assistant intern      1    1  bach degree
# ...                                   ...    ...  ...          ...
# 2076              senior project engineer   7888   15       master
# 2077           senior production engineer   7900   10  bach degree
# 2078     section head ii (quality system)   8800   38    prof cert
# 2079                   equipment engineer   9000   15  bach degree
# 2080  sr quality and reliability engineer  12000   23      diploma
#
#                     spec
# 0          manufacturing
# 1          manufacturing
# 2       electric-related
# 3                      -
# 4      chemistry-related
# ...                  ...
# 2076  civil/construction
# 2077   other engineering
# 2078     quality control
# 2079    electric-related
# 2080     quality control
#
# [2081 rows x 5 columns]
